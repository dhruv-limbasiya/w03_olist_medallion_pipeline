# %%
import pandas as pd

# %%
df =pd.read_csv("../data/raw/olist_customers_dataset.csv")

print(df["customer_state"].isnull().sum())

print(df.describe())
# Out:
# 0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
df = pd.read_csv("../data/raw/olist_products_dataset.csv")
print(df.isnull().sum())
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# total revenue
df = pd.read_csv("../data/raw/olist_order_items_dataset.csv")
df["revenue"] = df["price"] * df["order_item_id"]
print(df["revenue"].sum())
# Out:
# 15397738.61

# %%
# average order value
df = pd.read_csv("../data/raw/olist_order_items_dataset.csv")
df["revenue"] = df["price"] * df["order_item_id"]
print(df["revenue"].mean())
# Out:
# 136.6865389258766

# %%
# total customers
df = pd.read_csv("../data/raw/olist_customers_dataset.csv")
print(df["customer_id"].nunique())
# Out:
# 99441

# %%
# total products sold
df = pd.read_csv("../data/raw/olist_order_items_dataset.csv")
print(df["order_item_id"].sum())
# Out:
# 134936

# %%
# top 10 customers by revenue
df = pd.read_csv("../data/gold/customer_revenue.csv")
print(df.sort_values(by='total_revenue', ascending=False).head(10))
# Out:
#                             customer_id  total_orders  total_revenue
# 8475   1617b1357756262bfa56ab541c47bc16             1        13440.0
# 91284  ec5b2ba62e574342386871631fafd3fc             1         7160.0
# 76948  c6e2731c5b391845f6800c97401a43a9             1         6735.0
# 94398  f48d464a0baaea338cb25f816991ab1f             1         6729.0
# 24603  3fd6777bbce08a352fddd04e4a7cc8f6             1         6499.0
# 2049   05455dfa7cd02f13d132aa7a6a9729c6             1         5934.6
# 86248  df55c14d1476a9a3467f131269c2477f             1         4799.0
# 14182  24bbf5fd2f2e1b359ee7de94defc4a15             1         4690.0
# 86733  e0a2412720e9ea4f26c1ac985f6a7358             1         4599.9
# 23771  3d979689f636322c62418b6346b1c6d2             1         4590.0

# %%
# Paste top 10 rows from gold_product_revenue.csv
df = pd.read_csv("../data/gold/product_revenue.csv")
column = ["product_id", "product_category_name","total_revenue"]
print(df[column].sort_values(by="total_revenue", ascending=False).head(10).reset_index(drop=True))
# Out:
#                          product_id   product_category_name  total_revenue
# 0  bb50f2e236e5eea0100680137654686c            beleza_saude       63885.00
# 1  6cdd53843498f92890544667809f1595            beleza_saude       54730.20
# 2  d6160fb7873f184099d9bc95e30376af                     pcs       48899.34
# 3  d1c427060a0f73f6b889a5c7c61f2ac4  informatica_acessorios       47214.51
# 4  99a4788cb24856965c36a24e339b6058         cama_mesa_banho       43025.56
# 5  3dd2a17168ec895c781a9191c1e95ad7  informatica_acessorios       41082.60
# 6  25c38557cf793876c5abdd5931f922db                   bebes       38907.32
# 7  5f504b3a1c75b73d6151be81eb05bdc9              cool_stuff       37733.90
# 8  53b36df67ebb7c41585e8d54d6772e08      relogios_presentes       37683.42
# 9  aca2eb7d00ea1a7b8ebd4e68314663af        moveis_decoracao       37608.90

# %%
# Paste top 10 states from gold_state_revenue.csv
df = pd.read_csv("../data/gold/state_revenue.csv")
print(df.sort_values(by="total_revenue", ascending=False).head(10).reset_index(drop=True))
# Out:
#   customer_state  total_revenue
# 0             SP     5202955.05
# 1             RJ     1824092.67
# 2             MG     1585308.03
# 3             RS      750304.02
# 4             PR      683083.76
# 5             SC      520553.34
# 6             BA      511349.99
# 7             DF      302603.94
# 8             GO      294591.95
# 9             ES      275037.31

# %%
# Paste monthly revenue summary from gold_monthly_revenue.csv
df = pd.read_csv("../data/gold/monthly_revenue.csv")
print(df.sort_values(by="total_revenue",ascending=False).head(10).reset_index(drop=True))
# Out:
#   month_year  total_revenue
# 0    2017-11     1010271.37
# 1    2018-04      996647.75
# 2    2018-05      996517.68
# 3    2018-03      983213.44
# 4    2018-01      950030.36
# 5    2018-07      895507.22
# 6    2018-06      865124.31
# 7    2018-08      854686.33
# 8    2018-02      844178.71
# 9    2017-12      743914.17
